# %% [markdown]
# ##### IF/ELIF/ELSE

# %%
# 1. Check Positive, Negative, or Zero

num = int(input("Enter a number :"))

if num < 0:
    print("The number is negative")
elif num > 0:
    print("The number is positive")
else:        
    print("The number is zero")
# Out:
# The number is negative

# %%
# 2. Find the Greatest of Three Numbers (Without using max())

num_1 = 10
num_2 = 5
num_3 = 15

if num_1 >= num_2 and num_1>= num_3:
    print("num_1 is greater")
elif num_2 >= num_1 and num_2>=num3:
    print("num_2 is greater")
else:
    print("num_3 is greater")
# Out:
# num_3 is greater

# %%
# 3. Login System (Basic Logic)

user_name = "admin@123"
pass_word = 1234

username = input("Enter correct username: ")
password = int(input("Enter correct password: "))

if user_name == username and pass_word == password:
    print("Login Successfull")
else :
    print("Invalid credentials")
# Out:
# Login Successfull

# %%
# 4. Check Leap year

year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 ==0 ):
    print(f"{year} is a leap year")
else:    
    print("Not a leap year")
# Out:
# 2024 is a leap year
